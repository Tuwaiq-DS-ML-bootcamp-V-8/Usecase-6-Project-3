# %%
# !pip install ipyvizzu; ydata_profiling
# Out:
# Requirement already satisfied: ipyvizzu in c:\users\ghada\anaconda3\lib\site-packages (0.17.0)
# Requirement already satisfied: ydata_profiling in c:\users\ghada\anaconda3\lib\site-packages (4.11.0)
# Requirement already satisfied: IPython in c:\users\ghada\anaconda3\lib\site-packages (from ipyvizzu) (8.25.0)
# Requirement already satisfied: jsonschema in c:\users\ghada\anaconda3\lib\site-packages (from ipyvizzu) (4.19.2)
# Requirement already satisfied: scipy<1.14,>=1.4.1 in c:\users\ghada\anaconda3\lib\site-packages (from ydata_profiling) (1.13.1)
# Requirement already satisfied: pandas!=1.4.0,<3,>1.1 in c:\users\ghada\anaconda3\lib\site-packages (from ydata_profiling) (2.2.2)
# Requirement already satisfied: matplotlib<3.10,>=3.5 in c:\users\ghada\anaconda3\lib\site-packages (from ydata_profiling) (3.8.4)
# Requirement already satisfied: pydantic>=2 in c:\users\ghada\anaconda3\lib\site-packages (from ydata_profiling) (2.5.3)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\users\ghada\anaconda3\lib\site-packages (from ydata_profiling) (6.0.1)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in c:\users\ghada\anaconda3\lib\site-packages (from ydata_profiling) (3.1.4)
# Requirement already satisfied: visions<0.7.7,>=0.7.5 in c:\users\ghada\anaconda3\lib\site-packages (from visions[type_image_path]<0.7.7,>=0.7.5->ydata_profiling) (0.7.6)
# Requirement already satisfied: numpy<2.2,>=1.16.0 in c:\users\ghada\anaconda3\lib\site-packages (from ydata_profiling) (1.26.4)
# Requirement already satisfied: htmlmin==0.1.12 in c:\users\ghada\anaconda3\lib\site-packages (from ydata_profiling) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in c:\users\ghada\anaconda3\lib\site-packages (from ydata_profiling) (0.12.4)
# Requirement already satisfied: requests<3,>=2.24.0 in c:\users\ghada\anaconda3\lib\site-packages (from ydata_profiling) (2.32.2)
# Requirement already satisfied: tqdm<5,>=4.48.2 in c:\users\ghada\anaconda3\lib\site-packages (from ydata_profiling) (4.66.4)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in c:\users\ghada\anaconda3\lib\site-packages (from ydata_profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in c:\users\ghada\anaconda3\lib\site-packages (from ydata_profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\users\ghada\anaconda3\lib\site-packages (from ydata_profiling) (0.14.2)
# Requirement already satisfied: typeguard<5,>=3 in c:\users\ghada\anaconda3\lib\site-packages (from ydata_profiling) (4.3.0)
# Requirement already satisfied: imagehash==4.3.1 in c:\users\ghada\anaconda3\lib\site-packages (from ydata_profiling) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.3 in c:\users\ghada\anaconda3\lib\site-packages (from ydata_profiling) (1.9.3)
# Requirement already satisfied: dacite>=1.8 in c:\users\ghada\anaconda3\lib\site-packages (from ydata_profiling) (1.8.1)
# Requirement already satisfied: numba<1,>=0.56.0 in c:\users\ghada\anaconda3\lib\site-packages (from ydata_profiling) (0.59.1)
# Requirement already satisfied: PyWavelets in c:\users\ghada\anaconda3\lib\site-packages (from imagehash==4.3.1->ydata_profiling) (1.5.0)
# Requirement already satisfied: pillow in c:\users\ghada\anaconda3\lib\site-packages (from imagehash==4.3.1->ydata_profiling) (10.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ghada\anaconda3\lib\site-packages (from jinja2<3.2,>=2.11.1->ydata_profiling) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ghada\anaconda3\lib\site-packages (from matplotlib<3.10,>=3.5->ydata_profiling) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ghada\anaconda3\lib\site-packages (from matplotlib<3.10,>=3.5->ydata_profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ghada\anaconda3\lib\site-packages (from matplotlib<3.10,>=3.5->ydata_profiling) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ghada\anaconda3\lib\site-packages (from matplotlib<3.10,>=3.5->ydata_profiling) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ghada\anaconda3\lib\site-packages (from matplotlib<3.10,>=3.5->ydata_profiling) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ghada\anaconda3\lib\site-packages (from matplotlib<3.10,>=3.5->ydata_profiling) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ghada\anaconda3\lib\site-packages (from matplotlib<3.10,>=3.5->ydata_profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\ghada\anaconda3\lib\site-packages (from numba<1,>=0.56.0->ydata_profiling) (0.42.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ghada\anaconda3\lib\site-packages (from pandas!=1.4.0,<3,>1.1->ydata_profiling) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ghada\anaconda3\lib\site-packages (from pandas!=1.4.0,<3,>1.1->ydata_profiling) (2023.3)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\ghada\anaconda3\lib\site-packages (from phik<0.13,>=0.11.1->ydata_profiling) (1.4.2)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\ghada\anaconda3\lib\site-packages (from pydantic>=2->ydata_profiling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in c:\users\ghada\anaconda3\lib\site-packages (from pydantic>=2->ydata_profiling) (2.14.6)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\ghada\anaconda3\lib\site-packages (from pydantic>=2->ydata_profiling) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ghada\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata_profiling) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ghada\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata_profiling) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ghada\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata_profiling) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ghada\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata_profiling) (2024.8.30)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\ghada\anaconda3\lib\site-packages (from statsmodels<1,>=0.13.2->ydata_profiling) (0.5.6)
# Requirement already satisfied: colorama in c:\users\ghada\anaconda3\lib\site-packages (from tqdm<5,>=4.48.2->ydata_profiling) (0.4.6)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\ghada\anaconda3\lib\site-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata_profiling) (23.1.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\ghada\anaconda3\lib\site-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata_profiling) (3.2.1)
# Requirement already satisfied: decorator in c:\users\ghada\anaconda3\lib\site-packages (from IPython->ipyvizzu) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\ghada\anaconda3\lib\site-packages (from IPython->ipyvizzu) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\ghada\anaconda3\lib\site-packages (from IPython->ipyvizzu) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\ghada\anaconda3\lib\site-packages (from IPython->ipyvizzu) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\ghada\anaconda3\lib\site-packages (from IPython->ipyvizzu) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\ghada\anaconda3\lib\site-packages (from IPython->ipyvizzu) (0.2.0)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\ghada\anaconda3\lib\site-packages (from IPython->ipyvizzu) (5.14.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\ghada\anaconda3\lib\site-packages (from jsonschema->ipyvizzu) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\ghada\anaconda3\lib\site-packages (from jsonschema->ipyvizzu) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\ghada\anaconda3\lib\site-packages (from jsonschema->ipyvizzu) (0.10.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\ghada\anaconda3\lib\site-packages (from jedi>=0.16->IPython->ipyvizzu) (0.8.3)
# Requirement already satisfied: six in c:\users\ghada\anaconda3\lib\site-packages (from patsy>=0.5.6->statsmodels<1,>=0.13.2->ydata_profiling) (1.16.0)
# Requirement already satisfied: wcwidth in c:\users\ghada\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->IPython->ipyvizzu) (0.2.5)
# Requirement already satisfied: executing in c:\users\ghada\anaconda3\lib\site-packages (from stack-data->IPython->ipyvizzu) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\ghada\anaconda3\lib\site-packages (from stack-data->IPython->ipyvizzu) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\ghada\anaconda3\lib\site-packages (from stack-data->IPython->ipyvizzu) (0.2.2)

# %%
#Import all relevant libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore
from ydata_profiling import ProfileReport
 
## This statement allows the visuals to render within your Jupyter Notebook.
# %matplotlib inline

# %% [markdown]
# ## Loading the data
# We can now load the dataset into pandas using the read_csv() function. This converts the CSV file into a Pandas dataframe.

# %%
import kagglehub

# Download latest version
#riyadh_appart_folder = kagglehub.dataset_download("abdulmalikm/apartments-in-riyadh")

riyadh_aqqar_folder = kagglehub.dataset_download("myfaisal/riyadh-aqaar-dataset")

#riyadh_housing_folder = kagglehub.dataset_download("salmanshir/riyadhhousingdata")

# %%
import os
riyadh_aqqar_file =  os.listdir(riyadh_aqqar_folder)

# %%
#riyadh_housing_df =  pd.read_excel(f"{riyadh_aqqar_folder}/{riyadh_aqqar_file[0]}")
riyadh_aqqar_df =  pd.read_excel(f"{riyadh_aqqar_folder}/{riyadh_aqqar_file[0]}")

# %%
riyadh_aqqar_df.shape
# Out:
# (2155, 8)

# %%
#Read in the csv file and convert to a Pandas dataframe

# %% [markdown]
# ### Viewing the dataframe
# We can get a quick sense of the size of our dataset by using the shape method. This returns a tuple with the number of rows and columns in the dataset.

# %% [markdown]
# ## 1. Data Profiling:
# Data profiling is a comprehensive process of examining the data available in an existing dataset and collecting statistics and information about that data.

# %%
riyadh_aqqar_df.head()
# Out:
#   نوع العقار الغرض              المدينة                الحي     الواجهة  \
# 0        أرض   NaN   امارة منطقة الرياض             الرياض        غربية
# 1        أرض   NaN              الرياض           حي غرناطة       شمالية
# 2        أرض  سكني              الرياض           حي غرناطة   ثلاث شوارع
# 3        أرض  سكني              الرياض          حي اليرموك   ثلاث شوارع
# 4        أرض  سكني              الرياض    حي النسيم الغربي        غربية
#
#    المساحة  سعر المتر  السعر الإجمالي
# 0      375     2900.0         1087500
# 1      800     4800.0         3840000
# 2     1650     4800.0         7920000
# 3     1650     4800.0         7920000
# 4      750     3200.0         2400000

# %%
# Generate a profile report using ydata_profiling
profile = ProfileReport(riyadh_aqqar_df, title="Pandas Profiling Report", explorative=True)

# Display the report
profile.to_notebook_iframe()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;YData Profiling vv4.11.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-10-25 18:44:11.823723&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# @charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
#  */:root,[data-bs-theme=light]{--bs-blue:#0d6efd;--bs-indigo:#6610f2;--bs-purple:#6f42c1;--bs-pink:#d63384;--bs-red:#dc3545;--bs-orange:#fd7e14;--bs-yellow:#ffc107;--bs-green:#198754;--bs-teal:#20c997;--bs-cyan:#0dcaf0;--bs-black:#000;--bs-white:#fff;--bs-gray:#6c757d;--bs-gray-dark:#343a40;--bs-gray-100:#f8f9fa;--bs-gray-200:#e9ecef;--bs-gray-300:#dee2e6;--bs-gray-400:#ced4da;--bs-gray-500:#adb5bd;--bs-gray-600:#6c757d;--bs-gray-700:#495057;--bs-gray-800:#343a40;--bs-gray-900:#212529;--bs-primary:#0d6efd;--bs-secondary:#6c757d;--bs-success:#198754;--bs-info:#0dcaf0;--bs-warning:#ffc107;--bs-danger:#dc3545;--bs-light:#f8f9fa;--bs-dark:#212529;--bs-primary-rgb:13,110,253;--bs-secondary-rgb:108,117,125;--bs-success-rgb:25,135,84;--bs-info-rgb:13,202,240;--bs-warning-rgb:255,193,7;--bs-danger-rgb:220,53,69;--bs-light-rgb:248,249,250;--bs-dark-rgb:33,37,41;--bs-primary-text-emphasis:#052c65;--bs-secondary-text-emphasis:#2b2f32;--bs-success-text-emphasis:#0a3622;--bs-info-text-emphasis:#055160;--bs-warning-text-emphasis:#664d03;--bs-danger-text-emphasis:#58151c;--bs-light-text-emphasis:#495057;--bs-dark-text-emphasis:#495057;--bs-primary-bg-subtle:#cfe2ff;--bs-secondary-bg-subtle:#e2e3e5;--bs-success-bg-subtle:#d1e7dd;--bs-info-bg-subtle:#cff4fc;--bs-warning-bg-subtle:#fff3cd;--bs-danger-bg-subtle:#f8d7da;--bs-light-bg-subtle:#fcfcfd;--bs-dark-bg-subtle:#ced4da;--bs-primary-border-subtle:#9ec5fe;--bs-secondary-border-subtle:#c4c8cb;--bs-success-border-subtle:#a3cfbb;--bs-info-border-subtle:#9eeaf9;--bs-warning-border-subtle:#ffe69c;--bs-danger-border-subtle:#f1aeb5;--bs-light-border-subtle:#e9ecef;--bs-dark-border-subtle:#adb5bd;--bs-white-rgb:255,255,255;--bs-black-rgb:0,0,0;--bs-font-sans-serif:system-ui,-apple-system,&quot;Segoe UI&quot;,Roboto,&quot;Helvetica Neue&quot;,&quot;Noto Sans&quot;,&quot;Liberation Sans&quot;,Arial,sans-serif,&quot;Apple Color Emoji&quot;,&quot;Segoe UI Emoji&quot;,&quot;Segoe UI Symbol&quot;,&quot;Noto Color Emoji&quot;;--bs-font-monospace:SFMono-Regular,Menlo,Monaco,Consolas,&quot;Liberation Mono&quot;,&quot;Courier New&quot;,monospace;--bs-gradient:linear-gradient(180deg, rgba(255, 255, 255, 0.15), rgba(255, 255, 255, 0));--bs-body-font-family:var(--bs-font-sans-serif);--bs-body-font-size:1rem;--bs-body-font-weight:400;--bs-body-line-height:1.5;--bs-body-color:#212529;--bs-body-color-rgb:33,37,41;--bs-body-bg:#fff;--bs-body-bg-rgb:255,255,255;--bs-emphasis-color:#000;--bs-emphasis-color-rgb:0,0,0;--bs-secondary-color:rgba(33, 37, 41, 0.75);--bs-secondary-color-rgb:33,37,41;--bs-secondary-bg:#e9ecef;--bs-secondary-bg-rgb:233,236,239;--bs-tertiary-color:rgba(33, 37, 41, 0.5);--bs-tertiary-color-rgb:33,37,41;--bs-tertiary-bg:#f8f9fa;--bs-tertiary-bg-rgb:248,249,250;--bs-heading-color:inherit;--bs-link-color:#0d6efd;--bs-link-color-rgb:13,110,253;--bs-link-decoration:underline;--bs-link-hover-color:#0a58ca;--bs-link-hover-color-rgb:10,88,202;--bs-code-color:#d63384;--bs-highlight-color:#212529;--bs-highlight-bg:#fff3cd;--bs-border-width:1px;--bs-border-style:solid;--bs-border-color:#dee2e6;--bs-border-color-translucent:rgba(0, 0, 0, 0.175);--bs-border-radius:0.375rem;--bs-border-radius-sm:0.25rem;--bs-border-radius-lg:0.5rem;--bs-border-radius-xl:1rem;--bs-border-radius-xxl:2rem;--bs-border-radius-2xl:var(--bs-border-radius-xxl);--bs-border-radius-pill:50rem;--bs-box-shadow:0 0.5rem 1rem rgba(0, 0, 0, 0.15);--bs-box-shadow-sm:0 0.125rem 0.25rem rgba(0, 0, 0, 0.075);--bs-box-shadow-lg:0 1rem 3rem rgba(0, 0, 0, 0.175);--bs-box-shadow-inset:inset 0 1px 2px rgba(0, 0, 0, 0.075);--bs-focus-ring-width:0.25rem;--bs-focus-ring-opacity:0.25;--bs-focus-ring-color:rgba(13, 110, 253, 0.25);--bs-form-valid-color:#198754;--bs-form-valid-border-color:#198754;--bs-form-invalid-color:#dc3545;--bs-form-invalid-border-color:#dc3545}[data-bs-theme=dark]{color-scheme:dark;--bs-body-color:#dee2e6;--bs-body-color-rgb:222,226,230;--bs-body-bg:#212529;--bs-body-bg-rgb:33,37,41;--bs-emphasis-color:#fff;--bs-emphasis-color-rgb:2 ...

# %% [markdown]
# #### 1. Reliability:
# Evaluate the data's source and collection process to determine its trustworthiness.

# %%
# no source mentioned in the dataset

# %% [markdown]
# #### 2. Timeliness:
# Ensure the data is up-to-date and reflective of the current situation or the period of interest for the analysis.

# %%
# the data is updated since 2023

# %% [markdown]
# #### 3. Consistency:
#
# Confirm that the data is consistent within the dataset and across multiple data sources. For example, the same data point should not have different values in different places.

# %%
# only one dataset is used, consistency is not applied

# %% [markdown]
# #### 4. Relevance:

# %%
# all columns are relevant of riyadh aqqar

# %% [markdown]
# #### 5. Uniqueness:
# Check for and remove duplicate records to prevent skewed analysis results.

# %%
riyadh_aqqar_df.duplicated().sum()
# Out:
# 259

# %%
# go to delete duplicates columns

# %% [markdown]
# #### 6. Completeness:

# %%
#Display number missing values per column
riyadh_aqqar_df.isnull().sum()
# Out:
# نوع العقار         0
# الغرض             49
# المدينة            0
# الحي               0
# الواجهة            0
# المساحة            0
# سعر المتر          0
# السعر الإجمالي     0
# dtype: int64

# %%
# go to clean them

# %% [markdown]
# #### 7. Check Accuracy:

# %%
# check columns types 
riyadh_aqqar_df.dtypes
# Out:
# نوع العقار         object
# الغرض              object
# المدينة            object
# الحي               object
# الواجهة            object
# المساحة             int64
# سعر المتر         float64
# السعر الإجمالي      int64
# dtype: object

# %%
riyadh_aqqar_df.head()
# Out:
#   نوع العقار الغرض              المدينة                الحي     الواجهة  \
# 0        أرض   NaN   امارة منطقة الرياض             الرياض        غربية
# 1        أرض   NaN              الرياض           حي غرناطة       شمالية
# 2        أرض  سكني              الرياض           حي غرناطة   ثلاث شوارع
# 3        أرض  سكني              الرياض          حي اليرموك   ثلاث شوارع
# 4        أرض  سكني              الرياض    حي النسيم الغربي        غربية
#
#    المساحة  سعر المتر  السعر الإجمالي
# 0      375     2900.0         1087500
# 1      800     4800.0         3840000
# 2     1650     4800.0         7920000
# 3     1650     4800.0         7920000
# 4      750     3200.0         2400000

# %%
riyadh_aqqar_df['نوع العقار'].unique()
# Out:
# array(['أرض'], dtype=object)

# %%
riyadh_aqqar_df['الغرض'].unique()
# Out:
# array([nan, 'سكني', 'تجاري وسكني', 'تجاري'], dtype=object)

# %%
riyadh_aqqar_df['الحي'].unique()
# Out:
# array([' الرياض ', ' حي غرناطة ', ' حي اليرموك ', ' حي النسيم الغربي ',
#        ' حي الرمال ', ' حي الملك فيصل ', ' حي المعيزلة ', ' حي الشرق ',
#        ' حي المونسية ', ' حي الروضة ', ' حي المشرق ', ' حي الخليج ',
#        ' حي الشهداء ', ' حي الحمراء ', ' حي البيان ', ' حي قرطبة ',
#        ' حي القادسية ', ' حي النهضة ', ' حي الصناعية القديمة ',
#        ' حي العلا ', ' حي الجنادرية ', ' حي المعيزيلة ', ' حي السعادة ',
#        ' حي النسيم الشرقي ', ' حي خشم العان ', ' حي الصفا ',
#        ' حي اشبيلية ', ' طريق سعيد ابن زيد ', ' حي القدس ',
#        ' حي الاندلس ', ' حي الشعلة ', ' حي الندوة ', ' حي الفيحاء ', ' ',
#        ' امارة منطقة الرياض ', ' حي المنار ', ' حي السلام ',
#        ' حي الزاهر ', ' حي الجزيرة ', ' حي النظيم ', ' حي الازدهار ',
#        ' حي الملز ', ' حي العارض ', ' حي النرجس ', ' العيينة ',
#        ' حي الملقا ', ' حي الغنامية ', ' حي عرقة ', ' حي المهدية ',
#        ' حي الدار البيضاء ', ' حي سلطانة ', ' حي الندى ', ' حي ظهرة لبن ',
#        ' حي العين ', ' حي حطين ', ' حي الهدا ', ' حي طويق ',
#        ' حي المنصورة ', ' حي عريض ', ' حي المناخ ', ' حي القيروان ',
#        ' ضاحية نمار ', ' حي الخير ', ' حي الصحافة ', ' حي العوالي ',
#        ' حي النخيل ', ' حي ظهرة نمار ', ' طريق النفود ', ' حي الحزم ',
#        ' حي ضاحية نمار ', ' حي عكاظ ', ' حي بنبان ', ' حي السويدي ',
#        ' حي البديعة ', ' حي الملك فهد ', ' حي المحمدية ',
#        ' حي منفوحة الجديدة ', ' حي الربيع ', ' حي العقيق ', ' حي النفل ',
#        ' حي البرية ', ' حي المروة ', ' حي العزيزية ', ' حي شبرا ',
#        ' حي المربع ', ' حي الشفا ', ' حي السلي ', ' حي المغرزات ',
#        ' حي بدر ', ' حي المروج ', ' حي المشاعل ', ' شارع ابن ماجه ',
#        ' حي العليا ', ' حي المصانع ', ' حي الياسمين ', ' حي ثليم ',
#        ' ملهم ', ' حي اليمامة ', ' حي عقرباء ', ' حي الوادي ',
#        ' شارع السلطان محمد الفاتح ', ' حي طيبة ', ' حي الملك عبدالله ',
#        ' حي الرفيعة ', ' حي الناصرية ', ' حي أم الحمام الغربي ',
#        ' حي المصيف ', ' سدوس ', ' حي العريجاء الوسطى ', ' القرينة ',
#        ' حي نمار ', ' حي الزهرة ', ' حي الربوة ', ' حي الوزارات ',
#        ' حي منفوحة ', ' حي الحائر ', ' حي الفلاح ', ' حي الدفاع ',
#        ' حي الزهراء ', ' حي المصفاة ', ' حي نمار', ' المغرفية ',
#        ' حي عليشة ', ' حي المرسلات ', ' حي الريان ', ' حي الضباط ',
#        ' حي المنصورية ', ' حي الرحمانية ', ' القرينه ',
#        ' شارع سعيد بن عبدالله باقشير ', ' حي ديراب ', ' حي الغدير ',
#        ' حي ام سليم ', ' ضرما ', ' شارع العين ',
#        ' حي مطار الملك خالد الدولي ', ' حي لبن ', ' حي جرير ',
#        ' حي الفاروق ', ' حي السليمانية ', ' شارع عبدالله بن العاص ',
#        ' حي العريجاء الغربية ', ' حي العريجاء الغربي '], dtype=object)

# %%
riyadh_aqqar_df['الواجهة'].unique()
# Out:
# array(['غربية', 'شمالية', 'ثلاث شوارع', 'جنوبية', 'شرقية', 'شمالية شرقية',
#        'جنوبية شرقية', 'جنوبية غربية', 'شمالية غربية', 'أربع شوارع'],
#       dtype=object)

# %%
riyadh_aqqar_df['المساحة'].unique()
# Out:
# array([   375,    800,   1650,    750,   2400,    900,   1089,    450,
#           550,   3092,    381,    361,    412,   2115,   1560,   1798,
#          3000,    360,    420,    594,    300,    928,    239,    218,
#           572,   2000,    320,   1000,   1019,    432,   2940,   3663,
#          1849,    312,   3562,    810,   2100,   8400,    475,    514,
#           440,    437,   2825,   2520,   3905,     90,  22300,    500,
#          1050,  10000,    400,    930,    700,    763,    575,   5000,
#           543,    416,    362,    600,   5670,    747,   1125,   1500,
#          2250,    371,   5302,    357,   9900,   3900,    597,   2007,
#           751,    630,    870,    918,    429,    379,    454,    744,
#          4577,    720,    608,    760,   1930,    625,   1225,   1280,
#           306,   1200,    936,    840,    540,    510,    247,    621,
#           580,   4350,    372,    270,   1800,    234,    875,   1627,
#          9053,    590,  24000,  17927,    350,    771,    759,   1148,
#           435,    745,   1021,    825,   1020,    390,   2246,      1,
#          1250,    273,    648,   2800,    752,    343,    999,    756,
#           864,    833,    459,   1170,    255,    824,    937,    240,
#          3660,    653,   1119,   7500,   4000,    337,    252,  23059,
#          3493,   1080,    674,    470,    726,   1055,    856,   2317,
#          2184,  15730,    460,  11930,   6372,   2500,    871,    862,
#          2900,    480,   1160,    414,    472,    409,    585,    495,
#           517,   2048,   4675,    426,    516,    324,    525,    391,
#           348,   2394,    990,    160,    451,    109,    200,    352,
#          4262,   2816,    453,   5850,    405,   1400,    675,    425,
#           229,   4260,    735,   1419,    471,     85,    520,    410,
#          1950,   1987,    560,    385,    428,    944,    508,   1714,
#          1672,    399,    468,    325,  26966,    276,   1600,    345,
#           598,   5595,    407,    588,   4250,    438,   4772,    535,
#         15000,    455,    503,    962,    250,    354,    458,    782,
#           351,   9569,   4187,    731,    896,    638,  14835,    507,
#           614,    382,   4800,    403,    954,    969,   4956,    736,
#          2311,   1440,   3540,    706,    367,    787,    499,    210,
#          1151,   2529,    861,    850,    877,    445,    910,  10500,
#           536,    418,   2254,   1490,   1060,   2001,   1993,   2033,
#          2025,   2061,   4440,   5995,    802,   3157,    546,    805,
#           330,   2160,    705,   2172,    333,   2227,   2215,   2200,
#          1741,   2237,    742,    340,   2327,    785,   2340,    582,
#           386,    670,   7861,    692,   6889,   1843,   8217,    216,
#          2625,    890,    483,   1752,    408,    427,   2600,    225,
#          3600,  10941,    671,    511,   7420,   1270,  40000,    235,
#          1064,    486,    775,    537,    778,    769,    314,    780,
#           916,    660,    430,    259,    713,    434,    452,  39192,
#           422,    887,    690,    363,    559,   1373,    447,    960,
#          1988,    212,    393,   8058,   1292,    299,    938,    341,
#          5769,   1110,    370,    336,    295,   8664,    456,    828,
#           606,   4510,   4733,    874,    945,    570,    368,    318,
#           794,    374,   2205,    770,    880,    398,    288,    773,
#           915,  30000,   1213,   3260,    356,   1116,    599,    978,
#           359,    765,    490,   2338,    623,    719,    392,    924,
#          4697,    232,    383,    615,    378,   1210,    809,   3500,
#          1639,   8464,    294,   9600,    786,    627,    222,     36,
#           799,    308,    207,    989,    328,    646,   1450,   3903,
#           980,   2980,    384,   1062,    465,    406,  15797,    768,
#           996,    275,    329,    496,    728,    231,    889,   1493,
#           667,    686,   1517,   1168,   2512,   4060,    524,    975,
#           199,  15233,   1157,   2570,    732,   3890,    947,   2927,
#           624,    411,    921,    527,   2530,   1076,   1246,    940,
#          1647,   3002,   2080,    704,   1258,    904,    501,    484,
#           476,  11800,    571,   1144,    576,  57000,    248,    934,
#          2112,    457,    610,    305,    640,   2750,   3541,   7936,
#           444,    448,   7400,    402,   2450,   1900,   1375,   6000,
#          5300,    626,    891, 299684,   2508,   3241,   2790,    838,
#           650,   1608,   8100,   2880,   5450,   1850,   1561,    644,
#         96755,    244,    636,    971,   1173,    313], dtype=int64)

# %%
riyadh_aqqar_df['سعر المتر'].unique()
# Out:
# array([2.90000000e+03, 4.80000000e+03, 3.20000000e+03, 3.30000000e+03,
#        3.35000000e+03, 2.60000000e+03, 5.80000000e+02, 3.50000000e+03,
#        2.50000000e+03, 3.25000000e+03, 3.00000000e+03, 3.10000000e+03,
#        4.20000000e+03, 6.41000000e+03, 1.50000000e+03, 4.76000000e+02,
#        1.95000000e+03, 1.65000000e+03, 3.15000000e+03, 3.40000000e+03,
#        5.30000000e+03, 6.00000000e+03, 5.50000000e+03, 2.00000000e+03,
#        1.40000000e+03, 4.26000000e+02, 3.80000000e+03, 2.35000000e+03,
#        4.22000000e+02, 2.75000000e+03, 8.65000000e+02, 2.30000000e+03,
#        3.33300000e+03, 2.40000000e+03, 1.70000000e+03, 4.40000000e+03,
#        5.20000000e+02, 2.70000000e+03, 5.59000000e+02, 3.60000000e+03,
#        5.60000000e+02, 5.50000000e+02, 4.60000000e+02, 5.80000000e+03,
#        6.50000000e+02, 5.00000000e+02, 1.46600000e+03, 4.90000000e+03,
#        4.14000000e+02, 8.00000000e+03, 2.65000000e+03, 4.50000000e+03,
#        6.50000000e+03, 3.15000000e+02, 7.33300000e+03, 1.00000000e+03,
#        4.00000000e+03, 3.70000000e+03, 1.80000000e+03, 3.18000000e+02,
#        8.67000000e+02, 9.44000000e+02, 7.77000000e+02, 4.10000000e+03,
#        5.26000000e+02, 2.80000000e+03, 2.77700000e+03, 4.80000000e+02,
#        6.00000000e+02, 4.59000000e+02, 4.01900000e+03, 5.15000000e+02,
#        1.60000000e+03, 3.33900000e+03, 3.08000000e+03, 5.46000000e+02,
#        2.85000000e+03, 4.67000000e+02, 1.85000000e+03, 1.90000000e+03,
#        5.07000000e+02, 8.27000000e+02, 6.71000000e+02, 8.00000000e+02,
#        8.02000000e+02, 5.77800000e+03, 2.57000000e+03, 4.44000000e+02,
#        2.87100000e+03, 2.20200000e+03, 2.95400000e+03, 3.10000000e+02,
#        1.44100000e+03, 5.25000000e+02, 9.50000000e+02, 5.00000000e+03,
#        5.35000000e+02, 1.52000000e+03, 2.20000000e+03, 2.55000000e+03,
#        2.50000000e+02, 6.20000000e+03, 1.20000000e+03, 1.63000000e+03,
#        1.83300000e+03, 8.50000000e+03, 8.63100000e+03, 1.30000000e+03,
#        1.73900000e+03, 9.25000000e+02, 1.37500000e+03, 1.70900000e+03,
#        4.70000000e+03, 4.30000000e+03, 6.15000000e+03, 7.50000000e+03,
#        1.15000000e+03, 3.47200000e+03, 1.75000000e+03, 1.10000000e+03,
#        1.00000000e+04, 9.09000000e+02, 6.68000000e+02, 1.54700000e+03,
#        1.83400000e+03, 2.12500000e+03, 7.50000000e+02, 7.14000000e+02,
#        3.52100000e+03, 1.22000000e+03, 1.63200000e+03, 1.26000000e+03,
#        1.31700000e+03, 4.65000000e+03, 8.09000000e+02, 5.33000000e+02,
#        7.00000000e+03, 8.34000000e+02, 5.20000000e+03, 2.43900000e+03,
#        1.48800000e+03, 2.68000000e+03, 5.60000000e+03, 8.50000000e+02,
#        8.26000000e+02, 5.70000000e+03, 7.88800000e+03, 1.50000000e+04,
#        3.11100000e+03, 5.65000000e+03, 1.53300000e+03, 6.40000000e+03,
#        1.16000000e+03, 1.23000000e+03, 1.13300000e+03, 1.28000000e+03,
#        9.68000000e+02, 1.24000000e+03, 7.52000000e+02, 2.95000000e+03,
#        1.67000000e+03, 1.73000000e+03, 5.75000000e+02, 2.85700000e+03,
#        1.77500000e+03, 7.74000000e+02, 1.36000000e+03, 6.35000000e+03,
#        6.80000000e+03, 1.19000000e+03, 1.33300000e+03, 9.00000000e+02,
#        1.16700000e+03, 2.55500000e+03, 7.19000000e+02, 7.13000000e+02,
#        1.20967742e+03, 1.30400000e+03, 2.10000000e+03, 5.85000000e+03,
#        8.75000000e+02, 1.38800000e+03, 2.26600000e+03, 1.76100000e+03,
#        2.25000000e+03, 2.26100000e+03, 2.24000000e+03, 9.89100000e+03,
#        6.30000000e+03, 1.41300000e+03, 2.33800000e+03, 4.55500000e+03,
#        1.11100000e+03, 1.00400000e+03, 2.41600000e+03, 9.00000000e+03,
#        1.15500000e+03, 1.20500000e+03, 1.97800000e+04, 1.20100000e+03,
#        1.12000000e+03, 8.88000000e+02, 1.92500000e+03, 2.62500000e+03,
#        8.59000000e+02, 6.70000000e+03, 1.35000000e+03, 6.66700000e+03,
#        9.93000000e+02, 2.46000000e+03, 1.32000000e+03, 4.25000000e+03,
#        1.17900000e+03, 1.48000000e+03, 1.99700000e+03, 1.45500000e+03,
#        2.66700000e+03, 6.66000000e+02, 2.66600000e+03, 7.00000000e+02,
#        5.85700000e+03, 1.59000000e+03, 9.40000000e+02, 1.54600000e+03,
#        2.88900000e+03, 1.45000000e+03, 1.30500000e+03, 1.27000000e+03,
#        9.20000000e+02, 1.38000000e+03, 1.33500000e+03, 2.22200000e+03,
#        3.82000000e+03, 1.06300000e+03, 1.28300000e+03, 1.41500000e+03,
#        4.60000000e+03, 1.25000000e+03, 6.20000000e+02, 1.37000000e+03,
#        1.60400000e+03, 1.71700000e+03, 2.09500000e+03, 1.27400000e+03,
#        1.04200000e+03, 3.44400000e+03, 1.96500000e+03, 6.10000000e+03,
#        1.72000000e+03, 2.18500000e+03, 2.15000000e+03, 1.05000000e+04,
#        1.66700000e+03, 1.22200000e+03, 6.69500000e+03, 8.22000000e+02,
#        2.05000000e+03, 1.26600000e+03, 8.10000000e+02, 1.62500000e+03,
#        5.40000000e+03, 1.13800000e+03, 2.71200000e+03, 1.05000000e+03,
#        7.24000000e+02, 8.90000000e+02, 2.22500000e+03, 1.66600000e+03,
#        1.30600000e+03, 2.22300000e+03, 3.33500000e+03, 5.90000000e+03,
#        1.57000000e+03, 3.33000000e+03, 2.44600000e+03, 1.35800000e+03,
#        1.81200000e+03, 1.82200000e+03, 7.90000000e+03, 2.15300000e+03,
#        2.99000000e+03, 9.45000000e+05, 4.87500000e+03, 3.13000000e+03,
#        2.25000000e+04, 6.25000000e+02, 1.34000000e+03, 1.82900000e+03,
#        2.73200000e+03, 2.44400000e+03, 5.10000000e+02, 8.01000000e+02,
#        6.17500000e+03, 1.88000000e+03, 1.33330000e+04, 6.01100000e+03,
#        3.45000000e+03, 4.95000000e+03, 2.25500000e+03, 1.10000000e+04,
#        2.45000000e+03, 3.75000000e+03, 2.88000000e+03, 8.57200000e+03,
#        7.04000000e+02, 4.87000000e+02, 7.31700000e+03, 4.66000000e+02,
#        1.55000000e+03, 3.86000000e+02, 5.87000000e+02, 4.42000000e+02,
#        5.15000000e+03, 1.01700000e+03, 1.81000000e+03, 3.12500000e+03,
#        5.23000000e+02, 3.90000000e+02, 1.47600000e+03, 1.14600000e+03,
#        6.11000000e+02, 1.78500000e+03, 6.70000000e+02, 7.20000000e+03,
#        1.13400000e+03, 1.14000000e+03, 1.79300000e+03, 1.02500000e+03,
#        1.22600000e+03, 1.47500000e+03, 1.40400000e+03, 5.21000000e+02,
#        6.90000000e+02, 1.86700000e+03, 3.05000000e+03, 1.48700000e+03,
#        3.66600000e+03, 1.86800000e+03, 7.33000000e+02, 1.23700000e+03,
#        1.33950000e+04, 5.55500000e+03, 5.55000000e+03, 1.49000000e+03,
#        6.67000000e+02, 1.17000000e+03, 1.43000000e+03, 3.90000000e+03,
#        3.50000000e+02, 6.91000000e+02, 2.87500000e+03, 8.10000000e+03,
#        7.08000000e+02, 6.87000000e+02, 1.81800000e+03, 3.72000000e+02,
#        7.11000000e+02, 9.58000000e+02, 1.48400000e+03, 1.20820000e+04,
#        1.43800000e+03, 7.47000000e+02, 8.30000000e+03, 6.15400000e+03,
#        5.62500000e+03, 4.66600000e+03, 4.69000000e+02, 1.14500000e+03,
#        3.33400000e+03, 4.15000000e+03, 1.75000000e+04, 1.85000000e+04,
#        3.38000000e+02, 6.26000000e+03, 1.25300000e+03, 6.07000000e+02,
#        6.25000000e+03, 6.72000000e+03, 5.10000000e+03, 4.85000000e+03,
#        6.11900000e+03, 8.16000000e+02, 1.78000000e+03, 9.00000000e+01,
#        9.63000000e+02, 1.15800000e+03, 1.75800000e+03, 2.21300000e+03,
#        5.88000000e+02, 1.59500000e+03, 3.76000000e+02, 1.12600000e+03,
#        1.50400000e+03, 2.35000000e+02, 6.48000000e+02, 8.06000000e+02,
#        1.83700000e+03, 9.86000000e+02, 1.15700000e+03, 1.53800000e+03,
#        9.56000000e+02, 5.55000000e+02, 9.26000000e+02, 6.98700000e+03,
#        7.60000000e+03, 1.43400000e+03, 4.29600000e+03, 7.20000000e+02,
#        1.12500000e+03, 2.05900000e+03, 5.11000000e+02, 2.38000000e+03,
#        1.69500000e+03])

# %%
riyadh_aqqar_df['نوع العقار'].unique()
# Out:
# array(['أرض'], dtype=object)

# %%
# go to clean them

# %%
# check outliers 
# check price outliers
riyadh_aqqar_df.describe()
# Out:
#              المساحة      سعر المتر  السعر الإجمالي
# count    2155.000000    2155.000000    2.155000e+03
# mean     1568.780510    4356.648574    5.050271e+06
# std      9757.996967   35214.809640    3.141799e+07
# min         1.000000      90.000000    1.400000e+03
# 25%       413.000000    1365.000000    7.810000e+05
# 50%       670.000000    2570.000000    1.442000e+06
# 75%       900.000000    4000.000000    3.150000e+06
# max    299684.000000  945000.000000    8.930250e+08

# %%
riyadh_aqqar_df['المساحة'].sort_values(ascending=False)
# Out:
# 2086    299684
# 2087    299684
# 2126     96755
# 2017     57000
# 1266     40000
#          ...
# 95          90
# 600         85
# 1725        36
# 286          1
# 1446         1
# Name: المساحة, Length: 2155, dtype: int64

# %%
riyadh_aqqar_df[riyadh_aqqar_df['المساحة']==299684]
# Out:
#      نوع العقار        الغرض   المدينة         الحي     الواجهة  المساحة  \
# 2086        أرض  تجاري وسكني    الرياض      الرياض   أربع شوارع   299684
# 2087        أرض  تجاري وسكني   الرياض    حي الرمال   أربع شوارع   299684
#
#       سعر المتر  السعر الإجمالي
# 2086     1450.0       434541800
# 2087     1450.0       434541800

# %%
riyadh_aqqar_df['المساحة'].sort_values(ascending=False)
# Out:
# 2086    299684
# 2087    299684
# 2126     96755
# 2017     57000
# 1266     40000
#          ...
# 95          90
# 600         85
# 1725        36
# 286          1
# 1446         1
# Name: المساحة, Length: 2155, dtype: int64

# %%
# go delete outliers

# %%
riyadh_aqqar_df['السعر الإجمالي'].sort_values(ascending=False)
# Out:
# 1545    893025000
# 1547    850500000
# 2087    434541800
# 2086    434541800
# 1546    354375000
#           ...
# 519        106880
# 1581       100000
# 1725        93600
# 1446         1400
# 286          1400
# Name: السعر الإجمالي, Length: 2155, dtype: int64

# %%
# go to delete ouliers

# %% [markdown]
# ## 2. Data Cleaning:
#
# Preliminary findings from data profiling can lead to cleaning the data by:
# - Handling missing values
# - Correcting errors.
# - Dealing with outliers.
#
# -------------------

# %%
riyadh_aqqar_df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2150    False
# 2151    False
# 2152    False
# 2153    False
# 2154    False
# Length: 2155, dtype: bool

# %%
riyadh_aqqar_df.drop_duplicates(keep='first',inplace=True)

# %%
# show null rows
riyadh_aqqar_df[riyadh_aqqar_df['الغرض'].isnull()]
# Out:
#      نوع العقار الغرض              المدينة                الحي       الواجهة  \
# 0           أرض   NaN   امارة منطقة الرياض             الرياض          غربية
# 1           أرض   NaN              الرياض           حي غرناطة         شمالية
# 319         أرض   NaN              الرياض         حي القادسية          شرقية
# 320         أرض   NaN              الرياض           حي العارض         جنوبية
# 321         أرض   NaN              الرياض           حي العارض         جنوبية
# 322         أرض   NaN   امارة منطقة الرياض             الرياض         جنوبية
# 323         أرض   NaN   امارة منطقة الرياض             الرياض         شمالية
# 324         أرض   NaN              الرياض           حي النرجس         جنوبية
# 325         أرض   NaN   امارة منطقة الرياض             الرياض          غربية
# 326         أرض   NaN              الدرعية            العيينة         جنوبية
# 327         أرض   NaN   امارة منطقة الرياض             الرياض         جنوبية
# 328         أرض   NaN              الرياض          حي الجزيرة         شمالية
# 329         أرض   NaN              حريملاء             الرياض          شرقية
# 330         أرض   NaN   امارة منطقة الرياض             الرياض   جنوبية غربية
# 331         أرض   NaN              الرياض          حي الجزيرة         شمالية
# 333         أرض   NaN              الرياض          حي الجزيرة          شرقية
# 334         أرض   NaN              الرياض          حي الشهداء          شرقية
# 335         أرض   NaN              الرياض           حي الملقا          غربية
# 336         أرض   NaN              الرياض           حي النرجس         جنوبية
# 337         أرض   NaN              الرياض         حي الغنامية     ثلاث شوارع
# 338         أرض   NaN              الرياض           حي النرجس     ثلاث شوارع
# 339         أرض   NaN              الرياض        حي خشم العان         شمالية
# 340         أرض   NaN              الرياض             حي عرقة          غربية
# 341         أرض   NaN              الرياض          حي المهدية     ثلاث شوارع
# 343         أرض   NaN              الرياض    حي الدار البيضاء          شرقية
# 344         أرض   NaN              حريملاء             الرياض         شمالية
# 345         أرض   NaN              حريملاء             الرياض   شمالية غربية
# 346         أرض   NaN              الرياض        حي المعيزيلة         شمالية
# 347         أرض   NaN              الرياض          حي المهدية         شمالية
# 348         أرض   NaN              الرياض           حي سلطانة         جنوبية
# 349         أرض   NaN              الرياض         حي المونسية   جنوبية شرقية
# 350         أرض   NaN   امارة منطقة الرياض             الرياض          غربية
# 351         أرض   NaN              الرياض           حي النهضة         جنوبية
# 352         أرض   NaN              الرياض            حي الندى         جنوبية
# 353         أرض   NaN              الرياض           حي النرجس         شمالية
# 354         أرض   NaN              الرياض           حي النرجس          شرقية
# 659         أرض   NaN   امارة منطقة الرياض             الرياض         شمالية
# 660         أرض   NaN              الرياض           حي النرجس   جنوبية غربية
# 661         أرض   NaN              الرياض          حي المهدية     ثلاث شوارع
# 662         أرض   NaN              الرياض           حي النرجس          غربية
# 663         أرض   NaN              الرياض           حي النرجس          شرقية
# 1003        أرض   NaN              الرياض          ضاحية نمار         شمالية
# 1004        أرض   NaN              الرياض            حي الهدا          غربية
# 1005        أرض   NaN              الرياض            حي الهدا   شمالية شرقية
# 1006        أرض   NaN              الرياض           حي النرجس   شمالية شرقية
# 1007        أرض   NaN              الرياض          ضاحية نمار          غربية
# 1008        أرض   NaN              الرياض           حي النرجس          شرقية
#
#       المساحة  سعر المتر  السعر الإجمالي
# 0         375     2900.0         1087500
# 1         800     4800.0         3840000
# 319       543     2650.0         1438950
# 320       432     2650.0         1144800
# 321       747     2650.0         1979550
# 322       255     1500.0          382500
# 323       864     1500.0         1296000
# 324       432     4900.0         2116800
# 325       824     4900.0         4037600
# 326       937     4900.0         4591300
# 327       750     4900.0         3675000
# 328       240     4900.0         1176000
# 329       435     4900.0         2131500
# 330       900      800.0          720000
# 331       240      800.0          192000
# 333       900      800.0          720000
# 334       312     5000.0         1560000
# 335       900     5000.0         4500000
# 336       450     5000.0         2250000
# 337      3660     1000.0         3660000
# 338      3660     1000.0         3660000
# 339       750     1000.0          750000
# 340       653     4800.0         3134400
# 341       450     3150.0         1417500
# 343      1119     1600.0         1790400
# 344       375     1520.0          570000
# 345      7500     2000.0        15000000
# 346      4000     2200.0         8800000
# 347       810     2550.0         2065500
# 348       337     2550.0          859350
# 349       252     5000.0         1260000
# 350     23059      250.0         5764750
# 351       412     2800.0         1153600
# 352       412     2800.0         1153600
# 353      3493     6200.0        21656600
# 354       500     5500.0         2750000
# 659      1672    15000.0        25080000
# 660      1000     5000.0         5000000
# 661       450     3111.0         1399950
# 662       399     5650.0         2254350
# 663       160     5650.0          904000
# 1003     1993     1004.0         2000972
# 1004      856     6200.0         5307200
# 1005     2033     6200.0        12604600
# 1006     2033     6200.0        12604600
# 1007     2025     6200.0        12555000
# 1008      520     5300.0         2756000

# %%
riyadh_aqqar_df['الغرض'].fillna('بدون غرض',inplace=True)
# Out:
# C:\Users\Ghada\AppData\Local\Temp\ipykernel_4860\1346363617.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   riyadh_aqqar_df['الغرض'].fillna('بدون غرض',inplace=True)

# %%
# go back to 6th dimention --> Completeness

# %% [markdown]
# ### Correcting errors
#
# -------------------

# %%
riyadh_aqqar_df['المدينة'].unique()
# Out:
# array([' امارة منطقة الرياض', ' الرياض ', ' حي قرطبة ', ' حي الرمال ',
#        13843, ' الدرعية', ' حريملاء', ' العيينة ', ' حي عريض ', ' الرياض',
#        ' حي السلي ', ' الجبيلة ', ' حي القيروان ', ' ', ' ضرما',
#        ' حي المهدية ', ' رماح', ' حي ظهرة لبن ', ' حي العارض ', ' الخرج'],
#       dtype=object)

# %%
riyadh_aqqar_df['المدينة']='الرياض'

# %%
riyadh_aqqar_df['المدينة'].unique()
# Out:
# array(['الرياض'], dtype=object)

# %%
# exclude rows that is not equal to riyadh from riyadh_aqqar_df
riyadh_aqqar_df = riyadh_aqqar_df[riyadh_aqqar_df['الحي']!=' الرياض ']

# %%
# go back to 7th dimension Accuracy

# %% [markdown]
# ### Dealing with outliers:

# %%
riyadh_aqqar_df.describe()
# Out:
#              المساحة      سعر المتر  السعر الإجمالي
# count    1366.000000    1366.000000    1.366000e+03
# mean     1648.863836    4661.387994    5.828004e+06
# std      9033.701950   36111.550739    3.614159e+07
# min         1.000000      90.000000    1.400000e+03
# 25%       437.000000    1490.250000    9.468750e+05
# 50%       705.500000    2800.000000    1.751750e+06
# 75%      1000.000000    4400.000000    3.593700e+06
# max    299684.000000  945000.000000    8.930250e+08

# %%
# select numerical columns using pd_to_numeric
numric_df = riyadh_aqqar_df.select_dtypes(include=['int64', 'float64'])
zscore = numric_df.apply(zscore)

# %%
abs(zscore)
# Out:
#        المساحة  سعر المتر  السعر الإجمالي
# 1     0.094001   0.003840        0.055026
# 2     0.000126   0.003840        0.057905
# 3     0.000126   0.003840        0.057905
# 4     0.099538   0.040484        0.094884
# 5     0.083179   0.037713        0.057905
# ...        ...        ...             ...
# 2149  0.052696   0.114975        0.144723
# 2151  0.138296   0.087577        0.144706
# 2152  0.066316   0.063199        0.092144
# 2153  0.147930   0.073726        0.143987
# 2154  0.130323   0.082175        0.139169
#
# [1366 rows x 3 columns]

# %%
threshold = 3
outliers = riyadh_aqqar_df[(abs(zscore) > threshold).any(axis=1)]

# %%
outliers
# Out:
#      نوع العقار        الغرض المدينة           الحي       الواجهة  المساحة  \
# 1266        أرض  تجاري وسكني  الرياض       حي عريض     أربع شوارع    40000
# 1355        أرض         سكني  الرياض       العيينة     أربع شوارع    39192
# 1545        أرض  تجاري وسكني  الرياض          ملهم   شمالية شرقية      945
# 1547        أرض  تجاري وسكني  الرياض   حي القيروان          غربية      900
# 1612        أرض         سكني  الرياض     حي الرمال     ثلاث شوارع    30000
# 2017        أرض         سكني  الرياض     حي البيان         شمالية    57000
# 2087        أرض  تجاري وسكني  الرياض     حي الرمال     أربع شوارع   299684
# 2126        أرض         سكني  الرياض    حي المهدية          غربية    96755
#
#       سعر المتر  السعر الإجمالي
# 1266     1000.0        40000000
# 1355      620.0        24299040
# 1545   945000.0       893025000
# 1547   945000.0       850500000
# 1612     1600.0        48000000
# 2017       90.0         5130000
# 2087     1450.0       434541800
# 2126     1000.0        96755000

# %%
len(riyadh_aqqar_df)
# Out:
# 1366

# %%
# drop rows that is equal to outliers
riyadh_aqqar_df = riyadh_aqqar_df[~riyadh_aqqar_df.isin(outliers)].dropna()

# %%
len(riyadh_aqqar_df)
# Out:
# 1358

# %%
riyadh_aqqar_df.sample(20)
# Out:
#      نوع العقار        الغرض المدينة                الحي       الواجهة  \
# 968         أرض         سكني  الرياض         حي المهدية          غربية
# 1858        أرض  تجاري وسكني  الرياض        حي ظهرة لبن          غربية
# 961         أرض         سكني  الرياض      شارع ابن ماجه     ثلاث شوارع
# 1214        أرض         سكني  الرياض            حي حطين   شمالية غربية
# 1381        أرض         سكني  الرياض       حي ظهرة نمار          شرقية
# 1288        أرض         سكني  الرياض   حي الدار البيضاء          شرقية
# 2028        أرض  تجاري وسكني  الرياض           حي السلي         جنوبية
# 1302        أرض         سكني  الرياض          حي النرجس   جنوبية شرقية
# 986         أرض         سكني  الرياض         حي الفيحاء          غربية
# 1363        أرض         سكني  الرياض      حي ضاحية نمار         شمالية
# 48          أرض         سكني  الرياض         حي الشهداء         جنوبية
# 308         أرض  تجاري وسكني  الرياض         حي اليرموك         جنوبية
# 355         أرض         سكني  الرياض          حي النرجس          شرقية
# 2           أرض         سكني  الرياض          حي غرناطة     ثلاث شوارع
# 1550        أرض  تجاري وسكني  الرياض          حي الملقا   جنوبية غربية
# 701         أرض        تجاري  الرياض        حي ظهرة لبن         جنوبية
# 1115        أرض         سكني  الرياض            حي عرقة         شمالية
# 1538        أرض  تجاري وسكني  الرياض         حي اليرموك         جنوبية
# 893         أرض         سكني  الرياض         ضاحية نمار         جنوبية
# 2084        أرض  تجاري وسكني  الرياض         حي اشبيلية   شمالية غربية
#
#       المساحة  سعر المتر  السعر الإجمالي
# 968     744.0     1800.0       1339200.0
# 1858    400.0     2250.0        900000.0
# 961   10500.0     2700.0      28350000.0
# 1214   4000.0     1455.0       5820000.0
# 1381    440.0     1900.0        836000.0
# 1288    910.0     1270.0       1155700.0
# 2028   2400.0     2500.0       6000000.0
# 1302    475.0     4700.0       2232500.0
# 986     900.0     1000.0        900000.0
# 1363    887.0     1200.0       1064400.0
# 48      320.0     5300.0       1696000.0
# 308    1089.0     2954.0       3216906.0
# 355     500.0     5500.0       2750000.0
# 2      1650.0     4800.0       7920000.0
# 1550    570.0     7500.0       4275000.0
# 701     432.0     7000.0       3024000.0
# 1115    536.0     6000.0       3216000.0
# 1538   1089.0     1200.0       1306800.0
# 893    2311.0      800.0       1848800.0
# 2084    891.0     6000.0       5346000.0

# %%
riyadh_aqqar_df['الحي'].unique()
# Out:
# array([' حي غرناطة ', ' حي اليرموك ', ' حي النسيم الغربي ', ' حي الرمال ',
#        ' حي الملك فيصل ', ' حي المعيزلة ', ' حي الشرق ', ' حي المونسية ',
#        ' حي الروضة ', ' حي المشرق ', ' حي الخليج ', ' حي الشهداء ',
#        ' حي الحمراء ', ' حي البيان ', ' حي قرطبة ', ' حي القادسية ',
#        ' حي النهضة ', ' حي الصناعية القديمة ', ' حي العلا ',
#        ' حي الجنادرية ', ' حي المعيزيلة ', ' حي السعادة ',
#        ' حي النسيم الشرقي ', ' حي خشم العان ', ' حي الصفا ',
#        ' حي اشبيلية ', ' طريق سعيد ابن زيد ', ' حي القدس ',
#        ' حي الاندلس ', ' حي الشعلة ', ' حي الندوة ', ' حي الفيحاء ', ' ',
#        ' امارة منطقة الرياض ', ' حي المنار ', ' حي السلام ',
#        ' حي الزاهر ', ' حي الجزيرة ', ' حي النظيم ', ' حي الازدهار ',
#        ' حي الملز ', ' حي العارض ', ' حي النرجس ', ' العيينة ',
#        ' حي الملقا ', ' حي الغنامية ', ' حي عرقة ', ' حي المهدية ',
#        ' حي الدار البيضاء ', ' حي سلطانة ', ' حي الندى ', ' حي ظهرة لبن ',
#        ' حي العين ', ' حي حطين ', ' حي الهدا ', ' حي طويق ',
#        ' حي المنصورة ', ' حي عريض ', ' حي المناخ ', ' حي القيروان ',
#        ' ضاحية نمار ', ' حي الخير ', ' حي الصحافة ', ' حي العوالي ',
#        ' حي النخيل ', ' حي ظهرة نمار ', ' طريق النفود ', ' حي الحزم ',
#        ' حي ضاحية نمار ', ' حي عكاظ ', ' حي بنبان ', ' حي السويدي ',
#        ' حي البديعة ', ' حي الملك فهد ', ' حي المحمدية ',
#        ' حي منفوحة الجديدة ', ' حي الربيع ', ' حي العقيق ', ' حي النفل ',
#        ' حي البرية ', ' حي المروة ', ' حي العزيزية ', ' حي شبرا ',
#        ' حي المربع ', ' حي الشفا ', ' حي السلي ', ' حي المغرزات ',
#        ' حي بدر ', ' حي المروج ', ' حي المشاعل ', ' شارع ابن ماجه ',
#        ' حي العليا ', ' حي المصانع ', ' حي الياسمين ', ' حي ثليم ',
#        ' ملهم ', ' حي اليمامة ', ' حي عقرباء ', ' حي الوادي ',
#        ' شارع السلطان محمد الفاتح ', ' حي طيبة ', ' حي الملك عبدالله ',
#        ' حي الرفيعة ', ' حي الناصرية ', ' حي أم الحمام الغربي ',
#        ' حي المصيف ', ' سدوس ', ' حي العريجاء الوسطى ', ' القرينة ',
#        ' حي نمار ', ' حي الزهرة ', ' حي الربوة ', ' حي الوزارات ',
#        ' حي منفوحة ', ' حي الحائر ', ' حي الفلاح ', ' حي الدفاع ',
#        ' حي الزهراء ', ' حي المصفاة ', ' حي نمار', ' المغرفية ',
#        ' حي عليشة ', ' حي المرسلات ', ' حي الريان ', ' حي الضباط ',
#        ' حي المنصورية ', ' حي الرحمانية ', ' القرينه ',
#        ' شارع سعيد بن عبدالله باقشير ', ' حي ديراب ', ' حي الغدير ',
#        ' حي ام سليم ', ' ضرما ', ' شارع العين ',
#        ' حي مطار الملك خالد الدولي ', ' حي لبن ', ' حي جرير ',
#        ' حي الفاروق ', ' حي السليمانية ', ' شارع عبدالله بن العاص ',
#        ' حي العريجاء الغربية ', ' حي العريجاء الغربي '], dtype=object)

# %% [markdown]
# ## 3. Univariate Analysis:

# %% [markdown]
# ### 1. Univariate Graphical Analysis:
# Method to perform uni-variate analysis will depend on whether the variable type is categorical or numerical.

# %% [markdown]
# #### I. Categorical Variables:
#
# we’ll use frequency table to understand distribution of each category
# - Bar Chart (Ordinal) - Orderd
# - Pie Chart (Nominal) - non Orderd

# %% [markdown]
# #### II. Numerical Variables:
#
# we need to understand the central tendency and spread of the variable (Descriptive Analysis) using:
#    - Box plot
#    - Histogram

# %% [markdown]
# ### 2. Univariate Non-Graphical analysis:
#
# - Where is the center of the data? (location) --> **Measures of central tendency**
# - How much does the data vary? (scale) --> **Measure of variability**
# - What is the shape of the data? (shape) --> **Measures of variation combined with an average (measure of center) gives a good picture of the distribution of the data.**

# %% [markdown]
# ## 4. Bivariate/Multivariate Analysis:

# %% [markdown]
# **Categorical & Categorical --> (Stacked Column Chart)**

# %% [markdown]
# **Categorical & numerical --> (scatter plot, histogram, box plot)**

# %% [markdown]
# **numerical & numerical --> (Scatter plot, line chart)**

# %% [markdown]
# We could also use a correlation matrix to get more specific information about the relationship between these two variables.
